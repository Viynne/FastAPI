# %%
import os
from IPython.display import Image, display

# %%
image_path = '/Users/Vine/PycharmProjects/yolov3/images'

# %%
def list_content(file_path, display_list=False):
    """
    :param display_list: if True, prints out list of files
    :param file_path: Folder directory
    :return: a list of filenames in the folder path
    """
    image_names = os.listdir(image_path)
    if display_list is True:
        for images in image_names:
            print(images)
    return image_names

# %%
image_files = list_content(file_path=image_path, display_list=True)
# Out:
# apple.jpg
# apples.jpg
# car.jpg
# car1.jpg
# car2.jpg
# car3.jpg
# clock.jpg
# clock2.jpg
# clock3.jpg
# fruits.jpg
# oranges.jpg

# %%
import matplotlib.pyplot as plt

def display_object(filename):
    """

    :param filename: list of files to be displayed
    :return: displays objects
    """
    files_to_display = filename
    for files in files_to_display:
        print(f"Image Name:{files}")
        x = plt.imread(f"/Users/VIne/PycharmProjects/yolov3/images/{files}")
        display(Image())

# %%
display_object(filename=image_files)
# Out:
# Image Name:apple.jpg
#
# Image Name:apples.jpg
#
# Image Name:car.jpg
#
# Image Name:car1.jpg
#
# Image Name:car2.jpg
#
# Image Name:car3.jpg
#
# Image Name:clock.jpg
#
# Image Name:clock2.jpg
#
# Image Name:clock3.jpg
#
# Image Name:fruits.jpg
#
# Image Name:oranges.jpg

# %%
image_files = [
    'apple.jpg',
    'clock.jpg',
    'oranges.jpg',
    'car.jpg'
]

for image_file in image_files:
    print(f"\nDisplaying image: {image_file}")
    display(Image(filename=f"images/{image_file}"))
# Out:
# Displaying image: apple.jpg
#
# Displaying image: clock.jpg
#
# Displaying image: oranges.jpg
#
# Displaying image: car.jpg
